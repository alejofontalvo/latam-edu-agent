# %% [markdown]
# # LATAM EduAgent - Exploración inicial
#
# Notebook base para análisis exploratorio de datasets de pruebas estatales.

# %%
import pandas as pd

df = pd.read_csv('../data/raw/sample_latam_results.csv')
df.head()
